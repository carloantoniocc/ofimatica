# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pacientes = pd.read_excel('pacientes.xlsx', sheet_name='all_paciente')

# %%
## revision de datos
pacientes.columns
# Out:
# Index(['id', 'tipoDoc', 'rut', 'dv', 'numDoc', 'nombre', 'apPaterno',
#        'apMaterno', 'fechaNacimiento', 'genero', 'prevision', 'tramo', 'prais',
#        'funcionario'],
#       dtype='object')

# %%
pacientes.dtypes
# Out:
# id                   int64
# tipoDoc              int64
# rut                float64
# dv                  object
# numDoc              object
# nombre              object
# apPaterno           object
# apMaterno           object
# fechaNacimiento     object
# genero              object
# prevision           object
# tramo               object
# prais               object
# funcionario          int64
# dtype: object

# %%
pacientes['rut'].isnull().sum(axis=0)
pacientes['dv'].isnull().sum(axis=0)
pacientes['prais'].isnull().sum(axis=0)
pacientes['genero'].isnull().sum(axis=0)
pacientes['tramo'].isnull().sum(axis=0)
pacientes['numDoc'].isnull().sum(axis=0)
# Out:
# 770070

# %%
sns.set(style='dark', palette='dark', font='Verdana',font_scale=1)
## sns.barplot(x=['A','B','C'], y=[1,2,3])
sns.barplot(x=pacientes['genero'],y=pacientes['funcionario'] )
# Out:
# <Axes: xlabel='genero', ylabel='funcionario'>

# %%
n_by_state = pacientes.groupby("genero")["prais"].count()
n_by_state
# Out:
# genero
# Desconocido           60
# Femenino          448813
# Masculino         322602
# No Determinado        19
# Name: prais, dtype: int64

# %%
sns.displot(data=pacientes, x='tramo')

# %%
sns.displot(data=pacientes, x='genero', y="tramo")
# Out:
# c:\Users\Taller\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(data=pacientes, x='rut')

# %%
sns.displot(data=pacientes, x='genero', y="tramo",hue="prais")
